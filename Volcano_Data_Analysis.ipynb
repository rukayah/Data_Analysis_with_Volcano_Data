# %% [markdown]
# <a href="https://colab.research.google.com/github/TuringCollegeSubmissions/radeso-DS.1.1/blob/master/EDA_Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Import libraries

# %%
#import Relevant libraries
import pandas as pd
import numpy as np
import matplotlib as mpl
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# %% [markdown]
# # Read the datasets & Explore individually

# %%
eruption_data = pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-05-12/eruptions.csv')
volcano_data = pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-05-12/volcano.csv')
event_data = pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-05-12/events.csv')
sulfur_data = pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-05-12/sulfur.csv')
tr_data = pd.read_csv('https://raw.githubusercontent.com/rfordatascience/tidytuesday/master/data/2020/2020-05-12/tree_rings.csv')

# %% [markdown]
# # Volcano Data

# %% [markdown]
# Do some Exploratory Data Analyis

# %%
volcano_data.head() #find the first 5 rows
# Out:
#    volcano_number  ... population_within_100_km
# 0          283001  ...                  4071152
# 1          355096  ...                     9092
# 2          342080  ...                  7634778
# 3          213004  ...                  2253483
# 4          321040  ...                   393303
#
# [5 rows x 26 columns]

# %%
volcano_data.shape
# Out:
# (958, 26)

# %%
volcano_data.info() #find data type of each column
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 958 entries, 0 to 957
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   volcano_number            958 non-null    int64
#  1   volcano_name              958 non-null    object
#  2   primary_volcano_type      958 non-null    object
#  3   last_eruption_year        958 non-null    object
#  4   country                   958 non-null    object
#  5   region                    958 non-null    object
#  6   subregion                 958 non-null    object
#  7   latitude                  958 non-null    float64
#  8   longitude                 958 non-null    float64
#  9   elevation                 958 non-null    int64
#  10  tectonic_settings         958 non-null    object
#  11  evidence_category         958 non-null    object
#  12  major_rock_1              958 non-null    object
#  13  major_rock_2              958 non-null    object
#  14  major_rock_3              958 non-null    object
#  15  major_rock_4              958 non-null    object
#  16  major_rock_5              958 non-null    object
#  17  minor_rock_1              958 non-null    object
#  18  minor_rock_2              958 non-null    object
#  19  minor_rock_3              958 non-null    object
#  20  minor_rock_4              958 non-null    object
#  21  minor_rock_5              958 non-null    object
#  22  population_within_5_km    958 non-null    int64
#  23  population_within_10_km   958 non-null    int64
#  24  population_within_30_km   958 non-null    int64
#  25  population_within_100_km  958 non-null    int64
# dtypes: float64(2), int64(6), object(18)
# memory usage: 194.7+ KB

# %% [markdown]
# There seems to be no missing values

# %%
volcano_data.isnull().sum()  # find number of missing values
# Out:
# volcano_number              0
# volcano_name                0
# primary_volcano_type        0
# last_eruption_year          0
# country                     0
# region                      0
# subregion                   0
# latitude                    0
# longitude                   0
# elevation                   0
# tectonic_settings           0
# evidence_category           0
# major_rock_1                0
# major_rock_2                0
# major_rock_3                0
# major_rock_4                0
# major_rock_5                0
# minor_rock_1                0
# minor_rock_2                0
# minor_rock_3                0
# minor_rock_4                0
# minor_rock_5                0
# population_within_5_km      0
# population_within_10_km     0
# population_within_30_km     0
# population_within_100_km    0
# dtype: int64

# %%
#Use visualization to check for missing value
plt.figure(figsize=(20,9))
sns.heatmap(volcano_data.isnull(),cbar=False,yticklabels=False,cmap = 'viridis')

# %%
volcano_data.describe().T
# Out:
#                           count          mean  ...           75%           max
# volcano_number            958.0  2.985853e+05  ...  3.430880e+05  3.908290e+05
# latitude                  958.0  1.498468e+01  ...  4.079825e+01  7.108200e+01
# longitude                 958.0  2.353747e+01  ...  1.310455e+02  1.795800e+02
# elevation                 958.0  1.867027e+03  ...  2.548250e+03  6.879000e+03
# population_within_5_km    958.0  4.786046e+04  ...  4.642000e+03  5.783287e+06
# population_within_10_km   958.0  6.121775e+04  ...  2.073025e+04  5.783287e+06
# population_within_30_km   958.0  3.040444e+05  ...  2.565210e+05  7.073814e+06
# population_within_100_km  958.0  2.730174e+06  ...  2.981102e+06  4.064010e+07
#
# [8 rows x 8 columns]

# %%
#Convert all empty cell in the data to null value
volcano_data = volcano_data.replace(r'^\s*$', np.nan, regex=True)

# %%
volcano_data.isnull().sum()
# Out:
# volcano_number                0
# volcano_name                  0
# primary_volcano_type          0
# last_eruption_year            0
# country                       0
# region                        0
# subregion                     0
# latitude                      0
# longitude                     0
# elevation                     0
# tectonic_settings             0
# evidence_category             0
# major_rock_1                  0
# major_rock_2                256
# major_rock_3                642
# major_rock_4                833
# major_rock_5                917
# minor_rock_1                734
# minor_rock_2                871
# minor_rock_3                930
# minor_rock_4                956
# minor_rock_5                958
# population_within_5_km        0
# population_within_10_km       0
# population_within_30_km       0
# population_within_100_km      0
# dtype: int64

# %%
#Use visualization to check for missing value again
plt.figure(figsize=(20,9))
sns.heatmap(volcano_data.isnull(),cbar=False,yticklabels=False,cmap = 'viridis')

# %% [markdown]
# There are missing values in the data.

# %% [markdown]
# Examine the columns individually in the volcano data

# %%
volcano_data.select_dtypes('object').columns #select object type
# Out:
# Index(['volcano_name', 'primary_volcano_type', 'last_eruption_year', 'country',
#        'region', 'subregion', 'tectonic_settings', 'evidence_category',
#        'major_rock_1', 'major_rock_2', 'major_rock_3', 'major_rock_4',
#        'major_rock_5', 'minor_rock_1', 'minor_rock_2', 'minor_rock_3',
#        'minor_rock_4'],
#       dtype='object')

# %%
# find unique value for each of the object column
print(volcano_data['primary_volcano_type'].unique())
print(volcano_data['country'].unique())
print(volcano_data['region'].unique())
print(volcano_data['tectonic_settings'].unique())
print(volcano_data['evidence_category'].unique())
print(volcano_data['subregion'].unique())
print(volcano_data['major_rock_1'].unique())
# Out:
# ['Shield(s)' 'Stratovolcano' 'Stratovolcano(es)' 'Caldera' 'Submarine'
#  'Shield' 'Volcanic field' 'Fissure vent(s)' 'Compound' 'Complex'
#  'Pyroclastic shield' 'Pyroclastic cone(s)' 'Pyroclastic cone'
#  'Caldera(s)' 'Lava dome(s)' 'Lava cone' 'Crater rows' 'Maar(s)'
#  'Tuff cone(s)' 'Complex(es)' 'Subglacial' 'Lava dome' 'Lava cone(s)'
#  'Tuff cone' 'Lava cone(es)' 'Stratovolcano?']
# ['Japan' 'Chile' 'Guatemala' 'Turkey' 'United States' 'Ethiopia'
#  'Portugal' 'Indonesia' 'Russia' 'Ecuador' 'Eritrea' 'Canada' 'Vanuatu'
#  'Philippines' 'Papua New Guinea' 'Madagascar' 'France' 'Peru'
#  'Antarctica' 'Argentina' 'El Salvador' 'Nicaragua' 'Armenia' 'Djibouti'
#  'Costa Rica' 'Yemen' 'China' 'United Kingdom' 'Iceland' 'New Zealand'
#  'Undersea Features' 'Mexico' 'Kenya' 'Vietnam' 'Chile-Argentina' 'Sudan'
#  'Japan - administered by Russia' 'Saudi Arabia' 'Norway' 'Colombia'
#  'Uganda' 'Spain' 'Cameroon' 'Italy' 'China-North Korea'
#  'Colombia-Ecuador' 'Guatemala-El Salvador' 'North Korea-South Korea'
#  'Iran' 'Mongolia' 'Dominica' 'Cape Verde' 'Solomon Islands'
#  'Chile-Bolivia' 'Eritrea-Djibouti' 'South Korea'
#  'Syria-Jordan-Saudi Arabia' 'Australia' 'Tanzania' 'Bolivia'
#  'DR Congo-Rwanda' 'Comoros' 'Georgia' 'Grenada' 'Chad'
#  'Saint Kitts and Nevis' 'Ethiopia-Djibouti' 'Algeria' 'South Africa'
#  'Ethiopia-Kenya' 'Greece' 'Uganda-Rwanda' 'Fiji' 'Tonga' 'DR Congo'
#  'Burma (Myanmar)' 'Armenia-Azerbaijan' 'Saint Lucia' 'Netherlands'
#  'El Salvador-Guatemala' 'Samoa' 'Saint Vincent and the Grenadines'
#  'Mexico-Guatemala' 'Chile-Peru' 'Taiwan' 'Honduras' 'Niger' 'Panama'
#  'Germany']
# ['Japan, Taiwan, Marianas' 'South America' 'México and Central America'
#  'Mediterranean and Western Asia' 'Canada and Western USA'
#  'Africa and Red Sea' 'Atlantic Ocean' 'Indonesia'
#  'Kamchatka and Mainland Asia' 'Alaska' 'Kuril Islands'
#  'Melanesia and Australia' 'Philippines and SE Asia'
#  'Middle East and Indian Ocean' 'Antarctica' 'Iceland and Arctic Ocean'
#  'New Zealand to Fiji' 'Hawaii and Pacific Ocean' 'West Indies']
# ['Subduction zone / Continental crust (>25 km)'
#  'Intraplate / Continental crust (>25 km)'
#  'Rift zone / Intermediate crust (15-25 km)'
#  'Subduction zone / Crustal thickness unknown'
#  'Rift zone / Oceanic crust (< 15 km)'
#  'Subduction zone / Oceanic crust (< 15 km)'
#  'Subduction zone / Intermediate crust (15-25 km)'
#  'Rift zone / Continental crust (>25 km)'
#  'Intraplate / Oceanic crust (< 15 km)'
#  'Intraplate / Intermediate crust (15-25 km)' 'Unknown']
# ['Eruption Dated' 'Evidence Credible' 'Eruption Observed'
#  'Evidence Uncertain' 'Unrest / Holocene']
# ['Honshu' 'Northern Chile, Bolivia and Argentina' 'Guatemala' 'Turkey'
#  'USA (Washington)' 'Africa (northeastern) and Red Sea'
#  'Izu, Volcano, and Mariana Islands' 'Azores'
#  'Southern Chile and Argentina' 'Lesser Sunda Islands'
#  'Ryukyu Islands and Kyushu' 'Kamchatka Peninsula' 'Hokkaido'
#  'Aleutian Islands' 'Kuril Islands' 'Galapagos Islands' 'Ecuador' 'Canada'
#  'Halmahera' 'Vanuatu' 'Luzon' 'Sulawesi' 'New Ireland'
#  'Indian Ocean (western)' 'Indian Ocean (southern)' 'Peru'
#  'Antarctica and South Sandwich Islands' 'Alaska Peninsula'
#  'Central Chile and Argentina' 'El Salvador and Honduras' 'Mindanao'
#  'Nicaragua' 'Western Asia' 'Costa Rica' 'Middle East (southern)' 'Java'
#  'China (eastern)' 'Atlantic Ocean (central)' 'Iceland (northeastern)'
#  'New Zealand' 'Alaska (southwestern)' 'Pacific Ocean (northern)'
#  'Russia (southeastern)' 'North of Luzon' 'USA (Oregon)'
#  'Bougainville and Solomon Islands' 'Admiralty Islands' 'Banda Sea'
#  'Mexico' 'Africa (eastern)' 'Southeast Asia' 'Africa (northern)'
#  'Central Philippines' 'USA (Idaho)' 'USA (Utah)'
#  'Atlantic Ocean (southern)' 'Colombia' 'Iceland (southwestern)'
#  'Africa (central)' 'Western Europe' 'Africa (western)' 'Italy'
#  'USA (New Mexico)' 'Korea' 'USA (California)' 'New Britain'
#  'Middle East (western)' 'Mongolia' 'Sumatra'
#  "New Guinea and D'Entrecasteaux Islands" 'West Indies'
#  'Pacific Ocean (Chilean Islands)' 'Alaska (eastern)'
#  'Iceland (southeastern)' 'Iceland (southern)' 'Cape Verde Islands'
#  'Canary Islands' 'Pacific Ocean (eastern)' 'Hawaiian Islands'
#  'Iceland (western)' 'Alaska (western)' 'Atlantic Ocean (Jan Mayen)'
#  'Northeast of New Guinea' 'Krakatau' 'China (western)' 'Kermadec Islands'
#  'Pacific Ocean (southwestern)' 'Greece' 'Fiji Islands' 'Australia'
#  'Tonga Islands' 'Samoan and Wallis Islands' 'USA (Arizona)'
#  'USA (Nevada)' 'Taiwan' 'Santa Cruz Islands' 'Panama' 'USA (Wyoming)']
# ['Andesite / Basaltic Andesite' 'Dacite' 'Rhyolite'
#  'Basalt / Picro-Basalt' 'Trachyte / Trachydacite'
#  'Phono-tephrite /  Tephri-phonolite'
#  'Trachyandesite / Basaltic Trachyandesite'
#  'Trachybasalt / Tephrite Basanite' 'Foidite' 'Phonolite']

# %%
# find value count for each of the object column
print(volcano_data['primary_volcano_type'].value_counts())
print(volcano_data['country'].value_counts())
print(volcano_data['region'].value_counts())
print(volcano_data['tectonic_settings'].value_counts())
print(volcano_data['evidence_category'].value_counts())
print(volcano_data['subregion'].value_counts())
print(volcano_data['major_rock_1'].value_counts())
# Out:
# Stratovolcano          353
# Stratovolcano(es)      107
# Shield                  85
# Volcanic field          71
# Pyroclastic cone(s)     70
# Caldera                 65
# Complex                 46
# Shield(s)               33
# Submarine               27
# Lava dome(s)            26
# Fissure vent(s)         12
# Caldera(s)               9
# Compound                 9
# Maar(s)                  8
# Tuff cone(s)             7
# Pyroclastic shield       7
# Subglacial               5
# Crater rows              5
# Pyroclastic cone         4
# Lava dome                3
# Stratovolcano?           1
# Tuff cone                1
# Complex(es)              1
# Lava cone(es)            1
# Lava cone(s)             1
# Lava cone                1
# Name: primary_volcano_type, dtype: int64
# United States            99
# Indonesia                95
# Japan                    92
# Russia                   79
# Chile                    43
#                          ..
# Burma (Myanmar)           1
# Saint Lucia               1
# Guatemala-El Salvador     1
# Ethiopia-Kenya            1
# Cape Verde                1
# Name: country, Length: 89, dtype: int64
# South America                     117
# Japan, Taiwan, Marianas           102
# Indonesia                          95
# México and Central America         93
# Africa and Red Sea                 79
# Kamchatka and Mainland Asia        78
# Canada and Western USA             60
# Melanesia and Australia            45
# Alaska                             38
# Mediterranean and Western Asia     35
# Philippines and SE Asia            33
# Iceland and Arctic Ocean           29
# New Zealand to Fiji                29
# Middle East and Indian Ocean       27
# Kuril Islands                      25
# Antarctica                         25
# Atlantic Ocean                     21
# West Indies                        16
# Hawaii and Pacific Ocean           11
# Name: region, dtype: int64
# Subduction zone / Continental crust (>25 km)       511
# Intraplate / Continental crust (>25 km)            106
# Subduction zone / Oceanic crust (< 15 km)           77
# Rift zone / Continental crust (>25 km)              74
# Rift zone / Oceanic crust (< 15 km)                 69
# Subduction zone / Intermediate crust (15-25 km)     41
# Subduction zone / Crustal thickness unknown         40
# Rift zone / Intermediate crust (15-25 km)           21
# Intraplate / Oceanic crust (< 15 km)                14
# Intraplate / Intermediate crust (15-25 km)           4
# Unknown                                              1
# Name: tectonic_settings, dtype: int64
# Eruption Observed     428
# Eruption Dated        226
# Evidence Credible     193
# Evidence Uncertain     84
# Unrest / Holocene      27
# Name: evidence_category, dtype: int64
# Kamchatka Peninsula                  60
# Honshu                               43
# Central Chile and Argentina          38
# Africa (northeastern) and Red Sea    37
# Java                                 32
#                                      ..
# Atlantic Ocean (central)              1
# USA (Nevada)                          1
# Atlantic Ocean (Jan Mayen)            1
# China (western)                       1
# Pacific Ocean (southwestern)          1
# Name: subregion, Length: 98, dtype: int64
# Andesite / Basaltic Andesite                395
# Basalt / Picro-Basalt                       329
# Dacite                                       61
# Trachybasalt / Tephrite Basanite             57
# Rhyolite                                     47
# Trachyte / Trachydacite                      29
# Trachyandesite / Basaltic Trachyandesite     22
# Foidite                                      10
# Phonolite                                     6
# Phono-tephrite /  Tephri-phonolite            2
# Name: major_rock_1, dtype: int64

# %% [markdown]
# Plot a correlation chart to see if there is relationship between the variables

# %%
plt.figure(figsize=(20,9))
sns.heatmap(volcano_data.corr(), annot=True)

# %% [markdown]
# Which country has the most occurence of volcano since 1883?

# %%
country_volcano= volcano_data.groupby('country')['country'].count()
#print(type_volcano.sort_values(ascending=False))
plt.figure(figsize=(20,9))
country_volcano.sort_values(ascending=False).plot(kind='bar')

plt.title('Volcano by Countries')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# United State of America has the highest number of volcano in the recorded years closely followed by indonesia.

# %% [markdown]
# which type of volcano is the most occurence?

# %%
type_volcano= volcano_data.groupby('primary_volcano_type')['primary_volcano_type'].count()
#print(type_volcano.sort_values(ascending=False))
plt.figure(figsize=(8,9))
type_volcano.sort_values(ascending=False).plot(kind='bar', color="red")


plt.title('Type of Primary Volcano Occurence')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# The highest volcano type that has ever happened is "Stratovolcano" with a count of 353

# %% [markdown]
# Find which region it occured most?

# %%
region_volcano= volcano_data.groupby('region')['region'].count()
#print(type_volcano.sort_values(ascending=False))
plt.figure(figsize=(8,9))
region_volcano.sort_values(ascending=False).plot(kind='barh', color="purple")


plt.title('Regional Occurence')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# The highest sub region with most volcano is south America

# %% [markdown]
# what evidence category is the most common?

# %%
evidence_volcano= volcano_data.groupby('evidence_category')['evidence_category'].count()
#print(type_volcano.sort_values(ascending=False))
plt.figure(figsize=(8,9))
evidence_volcano.plot(kind='pie')
plt.show()

# %% [markdown]
# what subregion does the volcano occur most?

# %%
subregion_volcano= volcano_data.groupby('subregion')['subregion'].count()
#print(type_volcano.sort_values(ascending=False))
plt.figure(figsize=(20,20))
subregion_volcano.sort_values(ascending=False).plot(kind='barh', color="orange")


plt.title('frequency of subregion')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Kamchatka peninsula has the highest occurence of volcano in the subregion

# %% [markdown]
# Find out most volcano eruption country in each region and subregion.

# %%
crs_volcano= volcano_data.groupby(['region','subregion','country'])['country'].count()
print(crs_volcano.sort_values(ascending= False))
#plt.figure(figsize=(50,50))
#crs_volcano.sort_values(ascending=False).plot(kind='barh', color="orange")


#plt.title('Categorization of country, region and subregion')
#plt.ylabel('Frequency')
# Out:
# region                       subregion                          country
# Kamchatka and Mainland Asia  Kamchatka Peninsula                Russia                   60
# Japan, Taiwan, Marianas      Honshu                             Japan                    43
# Indonesia                    Java                               Indonesia                32
# México and Central America   Mexico                             Mexico                   28
# Africa and Red Sea           Africa (northeastern) and Red Sea  Ethiopia                 26
#                                                                                          ..
# México and Central America   El Salvador and Honduras           El Salvador-Guatemala     1
#                              Guatemala                          Guatemala-El Salvador     1
#                              Mexico                             Mexico-Guatemala          1
# Kamchatka and Mainland Asia  China (eastern)                    China-North Korea         1
# West Indies                  West Indies                        United Kingdom            1
# Name: country, Length: 155, dtype: int64

# %% [markdown]
# Russia, Japan,Indonesia, mexico, Ethopia are the most occuring countries in their region

# %% [markdown]
# Working with Numeric columns

# %%
# Working with numeric data
num = volcano_data.select_dtypes(np.number)
num.head()
numa = volcano_data[['elevation','population_within_5_km','population_within_10_km','population_within_30_km','population_within_100_km']]

# %% [markdown]
# Check for Outliers in each column

# %%
l = numa.columns.values
number_of_columns=5
number_of_rows = len(l)-1/number_of_columns
plt.figure(figsize=(20,40))
for i in range(0,len(l)):
    plt.subplot(number_of_rows + 1,number_of_columns,i+1)
    sns.set_style('whitegrid')
    sns.boxplot(y= numa[l[i]],color='green')
    plt.tight_layout()

# %% [markdown]
# The numerical varables has a lot of outliers

# %%
plt.figure(figsize=(5*number_of_columns,5*number_of_rows))
for i in range(0,len(l)):
    plt.subplot(number_of_rows + 1,number_of_columns,i+1)
    sns.histplot(numa[l[i]],kde=True)

# %%
numa.describe().T
# Out:
#                           count          mean  ...         75%         max
# elevation                 958.0  1.867027e+03  ...     2548.25      6879.0
# population_within_5_km    958.0  4.786046e+04  ...     4642.00   5783287.0
# population_within_10_km   958.0  6.121775e+04  ...    20730.25   5783287.0
# population_within_30_km   958.0  3.040444e+05  ...   256521.00   7073814.0
# population_within_100_km  958.0  2.730174e+06  ...  2981102.25  40640105.0
#
# [5 rows x 8 columns]

# %% [markdown]
# Other Analysis

# %% [markdown]
# Find the maximum height of volcano(elevation) per subregion. I used median because the data has outliers

# %%
subelevation_max= volcano_data.groupby('subregion')['elevation'].max()
#print(type_volcano.sort_values(ascending=False))
plt.figure(figsize=(20,20))
subelevation_max.sort_values(ascending=False).plot(kind='barh', color="orange")


plt.title('Max of elevation in each subregion')

plt.show()

# %% [markdown]
# Northern Chille, Bolivia and Argentina has the highest volcano height in the given range of years

# %% [markdown]
# # Eruption data

# %%
eruption_data.head() #print the first five rows
# Out:
#    volcano_number            volcano_name  ...  latitude longitude
# 0          266030                 Soputan  ...     1.112   124.737
# 1          343100              San Miguel  ...    13.434   -88.269
# 2          233020  Fournaise, Piton de la  ...   -21.244    55.708
# 3          345020      Rincon de la Vieja  ...    10.830   -85.324
# 4          353010              Fernandina  ...    -0.370   -91.550
#
# [5 rows x 15 columns]

# %%
eruption_data.shape
# Out:
# (11178, 15)

# %%
eruption_data.isnull().sum() #check for missing values
# Out:
# volcano_number               0
# volcano_name                 0
# eruption_number              0
# eruption_category            0
# area_of_activity          6484
# vei                       2906
# start_year                   1
# start_month                193
# start_day                  196
# evidence_method_dating    1280
# end_year                  6846
# end_month                 6849
# end_day                   6852
# latitude                     0
# longitude                    0
# dtype: int64

# %% [markdown]
# This data has columns with a lot of missing values

# %% [markdown]
# Find percentage of missing values and plot

# %%
#find the percentage of missing value for each column
mask = eruption_data.isnull()
total = mask.sum()
percent = 100*mask.mean()
missing_data = pd.concat([total, percent], axis=1,join='outer',
keys=['count_missing', 'perc_missing'])
missing_data.sort_values(by='perc_missing', ascending=False,
inplace=True)
missing_data
# Out:
#                         count_missing  perc_missing
# end_day                          6852     61.298980
# end_month                        6849     61.272142
# end_year                         6846     61.245303
# area_of_activity                 6484     58.006799
# vei                              2906     25.997495
# evidence_method_dating           1280     11.451065
# start_day                         196      1.753444
# start_month                       193      1.726606
# start_year                          1      0.008946
# volcano_number                      0      0.000000
# volcano_name                        0      0.000000
# eruption_number                     0      0.000000
# eruption_category                   0      0.000000
# latitude                            0      0.000000
# longitude                           0      0.000000

# %%
#visualize the missing values
nullable_columns = eruption_data.columns[mask.any()].tolist()
msno.matrix(eruption_data[nullable_columns].sample(500))

# %% [markdown]
# Find the valuecount of startday,endday, startmonth, endmonth, startyear, endyear

# %%
print(eruption_data['start_day'].value_counts())
print(eruption_data['start_month'].value_counts())
print(eruption_data['start_year'].value_counts())
print(eruption_data['end_day'].value_counts())
print(eruption_data['end_month'].value_counts())
print(eruption_data['end_year'].value_counts())
# Out:
# 0.0     5851
# 16.0     451
# 2.0      292
# 1.0      249
# 15.0     242
# 5.0      183
# 4.0      166
# 25.0     164
# 18.0     160
# 11.0     157
# 26.0     156
# 8.0      151
# 29.0     150
# 3.0      149
# 12.0     147
# 27.0     146
# 9.0      144
# 10.0     144
# 21.0     142
# 13.0     142
# 7.0      142
# 23.0     139
# 24.0     138
# 14.0     138
# 17.0     138
# 28.0     136
# 6.0      132
# 22.0     132
# 19.0     132
# 30.0     125
# 20.0     124
# 31.0     120
# Name: start_day, dtype: int64
# 0.0     5033
# 7.0      633
# 1.0      567
# 3.0      508
# 12.0     495
# 2.0      494
# 5.0      489
# 11.0     483
# 4.0      482
# 6.0      467
# 8.0      459
# 9.0      452
# 10.0     423
# Name: start_month, dtype: int64
#  2004.0    54
#  2008.0    53
#  1986.0    51
#  1973.0    51
#  2002.0    51
#            ..
# -3541.0     1
#  1433.0     1
# -6270.0     1
# -7320.0     1
# -5830.0     1
# Name: start_year, Length: 1694, dtype: int64
# 0.0     733
# 16.0    467
# 26.0    153
# 15.0    150
# 2.0     141
# 1.0     130
# 17.0    129
# 28.0    127
# 5.0     122
# 30.0    120
# 18.0    117
# 25.0    115
# 13.0    113
# 27.0    108
# 24.0    105
# 12.0    104
# 14.0    104
# 4.0     102
# 19.0     99
# 9.0      98
# 8.0      92
# 10.0     92
# 20.0     87
# 21.0     86
# 6.0      85
# 23.0     85
# 29.0     82
# 22.0     80
# 7.0      80
# 31.0     77
# 11.0     74
# 3.0      69
# Name: end_day, dtype: int64
# 7.0     382
# 12.0    377
# 9.0     354
# 8.0     352
# 10.0    349
# 4.0     332
# 6.0     330
# 5.0     329
# 3.0     320
# 1.0     316
# 11.0    309
# 2.0     306
# 0.0     273
# Name: end_month, dtype: int64
# 2020.0    52
# 2004.0    47
# 2000.0    45
# 1986.0    44
# 1974.0    44
#           ..
# 235.0      1
# 1650.0     1
# 1748.0     1
# 1302.0     1
# 472.0      1
# Name: end_year, Length: 455, dtype: int64

# %% [markdown]
# Find the average startday,endday, startmonth, endmonth, startyear, endyear

# %%
print(round(eruption_data['start_day'].mean(), 1))
print(round(eruption_data['start_month'].mean(), 1))
print(round(eruption_data['start_year'].mean(), 1))
print(round(eruption_data['end_day'].mean(), 1))
print(round(eruption_data['end_month'].mean(), 1))
print(round(eruption_data['end_year'].mean(), 1))
# Out:
# 7.0
# 3.5
# 622.8
# 13.3
# 6.2
# 1917.3

# %% [markdown]
# Make a copy of the eruption data and drop the rows containing 0 in the end day column

# %%
N_eruption = eruption_data.copy()
N_eruption.shape
# Out:
# (11178, 15)

# %%
N_eruption.dropna(subset=['end_day','start_day'], inplace = True)

# %%
N_eruption.isnull().sum()
# Out:
# volcano_number               0
# volcano_name                 0
# eruption_number              0
# eruption_category            0
# area_of_activity          2267
# vei                        146
# start_year                   0
# start_month                  0
# start_day                    0
# evidence_method_dating     305
# end_year                     0
# end_month                    0
# end_day                      0
# latitude                     0
# longitude                    0
# dtype: int64

# %%
N_eruption.head()
# Out:
#    volcano_number            volcano_name  ...  latitude longitude
# 0          266030                 Soputan  ...     1.112   124.737
# 1          343100              San Miguel  ...    13.434   -88.269
# 2          233020  Fournaise, Piton de la  ...   -21.244    55.708
# 3          345020      Rincon de la Vieja  ...    10.830   -85.324
# 4          353010              Fernandina  ...    -0.370   -91.550
#
# [5 rows x 15 columns]

# %% [markdown]
# convert date columns to intergers

# %%
N_eruption['start_day'] = N_eruption['start_day'].apply(np.int64)
N_eruption['start_month'] = N_eruption['start_month'].apply(np.int64)
N_eruption['start_year'] = N_eruption['start_year'].apply(np.int64)
N_eruption['end_day'] = N_eruption['end_day'].apply(np.int64)
N_eruption['end_month'] = N_eruption['end_month'].apply(np.int64)
N_eruption['end_year'] = N_eruption['end_year'].apply(np.int64)

# %% [markdown]
# combine the start_day,start_month and start_year column into one and name it start_date. Do so for end variables too.

# %%
N_eruption['start_date'] = N_eruption['start_day'].map(str) + '-' + N_eruption['start_month'].map(str) + '-' + N_eruption['start_year'].map(str)
N_eruption['end_date'] = N_eruption['end_day'].map(str) + '-' + N_eruption['end_month'].map(str) + '-' + N_eruption['end_year'].map(str)
print(N_eruption.head(2))
# Out:
#    volcano_number volcano_name  ...  start_date   end_date
# 0          266030      Soputan  ...   23-3-2020   2-4-2020
# 1          343100   San Miguel  ...   22-2-2020  22-2-2020
#
# [2 rows x 17 columns]

# %% [markdown]
# Make a line plot

# %%
plt.figure(figsize = (20,9))
start_day = N_eruption.groupby('start_day')['start_day'].count()
print(start_day.sort_values(ascending=False))
start_day.plot(kind="line")
# Out:
# start_day
# 0     550
# 16    327
# 1     167
# 5     146
# 15    145
# 2     142
# 26    132
# 25    128
# 11    124
# 4     122
# 29    120
# 7     116
# 21    116
# 27    116
# 17    114
# 3     113
# 8     113
# 18    112
# 9     112
# 19    112
# 10    112
# 23    110
# 13    109
# 12    108
# 28    105
# 24    105
# 14    102
# 22    101
# 6      98
# 30     96
# 20     94
# 31     59
# Name: start_day, dtype: int64

# %% [markdown]
# This has just confirmed our findings above that the majority of eruption started on the 16th day of the month. zero(0) indicates missing values

# %% [markdown]
# let us plot for end day too

# %%
plt.figure(figsize = (20,9))
end_day = N_eruption.groupby('end_day')['end_day'].count()
print(end_day.sort_values(ascending=False))
end_day.plot(kind="line")
# Out:
# end_day
# 0     733
# 16    467
# 26    153
# 15    150
# 2     141
# 1     130
# 17    129
# 28    127
# 5     122
# 30    120
# 18    117
# 25    115
# 13    113
# 27    108
# 24    105
# 14    104
# 12    104
# 4     102
# 19     99
# 9      98
# 10     92
# 8      92
# 20     87
# 21     86
# 6      85
# 23     85
# 29     82
# 7      80
# 22     80
# 31     77
# 11     74
# 3      69
# Name: end_day, dtype: int64

# %% [markdown]
# This has just confirmed our findings above that the majority of eruption also ended on the 16th day of the month. zero(0) indicates missing values

# %%
volcano_data.shape
# Out:
# (958, 26)

# %% [markdown]
# Merge the eruption_data with volcano_data on volcano_number

# %%
merged = pd.merge(volcano_data, eruption_data,on='volcano_number',how='inner')
merged.shape
# Out:
# (9559, 40)

# %% [markdown]
# Let us do some analysis on our merged data

# %%
merged.isnull().sum()
# Out:
# volcano_number                 0
# volcano_name_x                 0
# primary_volcano_type           0
# last_eruption_year             0
# country                        0
# region                         0
# subregion                      0
# latitude_x                     0
# longitude_x                    0
# elevation                      0
# tectonic_settings              0
# evidence_category              0
# major_rock_1                   0
# major_rock_2                2103
# major_rock_3                6053
# major_rock_4                8427
# major_rock_5                9203
# minor_rock_1                6389
# minor_rock_2                8110
# minor_rock_3                9177
# minor_rock_4                9470
# minor_rock_5                9559
# population_within_5_km         0
# population_within_10_km        0
# population_within_30_km        0
# population_within_100_km       0
# volcano_name_y                 0
# eruption_number                0
# eruption_category              0
# area_of_activity            5212
# vei                         2399
# start_year                     1
# start_month                  171
# start_day                    174
# evidence_method_dating      1007
# end_year                    5865
# end_month                   5868
# end_day                     5871
# latitude_y                     0
# longitude_y                    0
# dtype: int64

# %% [markdown]
# Make a copy and drop all rows where start day is null

# %%
N_merged = merged.copy()
N_merged.shape
# Out:
# (9559, 40)

# %%
N_merged.dropna(subset=['start_day'], inplace = True)

# %%
N_merged.shape
# Out:
# (9385, 40)

# %% [markdown]
# Count the most occurence start_day for each country

# %%
#group by country on start day and count
plt.figure(figsize = (20,20))
country_day = N_merged.groupby('country')['start_day'].mean()
print(country_day .sort_values(ascending=False))
country_day.plot(kind="barh")
# Out:
# country
# Ethiopia-Djibouti    31.000000
# South Africa         20.000000
# Colombia-Ecuador     17.000000
# Grenada              15.600000
# Cape Verde           12.416667
#                        ...
# Netherlands           0.000000
# Mongolia              0.000000
# Madagascar            0.000000
# Germany               0.000000
# Iran                  0.000000
# Name: start_day, Length: 76, dtype: float64

# %% [markdown]
# The figure shows that USA with the highest number of volcano for the given years on average, the eruption starts on the 5th day of the month.

# %% [markdown]
# # events_data

# %%
event_data.head()
# Out:
#    volcano_number     volcano_name  ...  event_date_month  event_date_day
# 0          210020  Chaine des Puys  ...               NaN             NaN
# 1          210020  Chaine des Puys  ...               NaN             NaN
# 2          210020  Chaine des Puys  ...               NaN             NaN
# 3          210020  Chaine des Puys  ...               NaN             NaN
# 4          210020  Chaine des Puys  ...               NaN             NaN
#
# [5 rows x 10 columns]

# %%
event_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41322 entries, 0 to 41321
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   volcano_number       41322 non-null  int64
#  1   volcano_name         41322 non-null  object
#  2   eruption_number      41322 non-null  int64
#  3   eruption_start_year  41322 non-null  int64
#  4   event_number         41322 non-null  int64
#  5   event_type           41322 non-null  object
#  6   event_remarks        4880 non-null   object
#  7   event_date_year      10007 non-null  float64
#  8   event_date_month     7132 non-null   float64
#  9   event_date_day       5923 non-null   float64
# dtypes: float64(3), int64(4), object(3)
# memory usage: 3.2+ MB

# %%
event_data.describe().T
# Out:
#                        count           mean  ...        75%       max
# volcano_number       41322.0  296428.862616  ...  342090.00  600000.0
# eruption_number      41322.0   15428.928029  ...   18081.75   22352.0
# eruption_start_year  41322.0     850.534679  ...    1968.00    2020.0
# event_number         41322.0  127402.193819  ...  141701.75  153202.0
# event_date_year      10007.0    1365.646947  ...    1977.00    2020.0
# event_date_month      7132.0       6.382081  ...       9.00      12.0
# event_date_day        5923.0      15.461759  ...      23.00      31.0
#
# [7 rows x 8 columns]

# %%
print(event_data['event_type'].value_counts())
# Out:
# VEI (Explosivity Index)                9194
# Explosion                              7825
# Ash                                    4110
# Lava flow(s)                           3195
# Earthquakes (undefined)                1777
# Phreatic activity                      1508
# Pyroclastic flow                       1399
# Property damage                        1079
# Lahar or mudflow                        785
# Pumice                                  716
# Scoria                                  682
# Lava dome formation                     668
# Blocks                                  632
# Lapilli                                 616
# Tephra                                  611
# Volcanic tremor                         604
# Fatalities                              585
# Cinder cone formation                   512
# Evacuations                             497
# Bombs                                   423
# Loud audible noises                     403
# Lava fountains                          323
# Eruption cloud                          283
# Seismicity (volcanic)                   252
# Volcanic smoke                          237
# Lightning                               209
# Debris avalanches                       205
# Crater formation                        188
# Lava lake                               176
# Phreatomagmatic eruption                170
# Flames                                  133
# Deformation (inflation)                 123
# Island formation                        115
# Fauna kill                              112
# Jokulhaup                               107
# Fumarolic or solfataric                 103
# Caldera formation                        95
# Edifice destroyed                        83
# Tsunami                                  80
# Deformation (deflation)                  77
# Thermal anomaly                          69
# Glow                                     65
# Earthquake (tectonic)                    49
# Directed explosion                       45
# Ash Plume                                44
# Spine formation                          33
# Observation                              27
# Ashfall                                  23
# Partial collapse at end of eruption      19
# Deformation (undefined)                  18
# Fissure formation                        13
# Liquid sulfur                            10
# Mud                                       8
# Incandescent ejecta                       3
# Water fountain                            3
# Degassing                                 1
# Name: event_type, dtype: int64

# %%
event_data.isnull().sum()
# Out:
# volcano_number             0
# volcano_name               0
# eruption_number            0
# eruption_start_year        0
# event_number               0
# event_type                 0
# event_remarks          36442
# event_date_year        31315
# event_date_month       34190
# event_date_day         35399
# dtype: int64

# %% [markdown]
# We want to make use of the event type in event data, hence i would be merging it with the volcano data

# %%
volcano_event = pd.merge(volcano_data, event_data,on='volcano_number',how='inner')
volcano_event.shape
# Out:
# (36075, 35)

# %% [markdown]
# What is the event_type common to each region?

# %%
#group by region on event_type and count
plt.figure(figsize = (20,20))
region_event_type  =volcano_event.groupby(['region','event_type'])['event_type'].count()
sorted = region_event_type .sort_values(ascending=False).head(10)
print(sorted)
sorted.plot(kind="barh")
# Out:
# region                       event_type
# Japan, Taiwan, Marianas      VEI (Explosivity Index)    1360
# Indonesia                    VEI (Explosivity Index)    1261
# Japan, Taiwan, Marianas      Explosion                  1084
# Indonesia                    Explosion                   998
# South America                VEI (Explosivity Index)     869
# México and Central America   VEI (Explosivity Index)     765
# South America                Explosion                   743
# Japan, Taiwan, Marianas      Ash                         720
# México and Central America   Explosion                   656
# Kamchatka and Mainland Asia  Explosion                   630
# Name: event_type, dtype: int64

# %% [markdown]
# South America which has the highest count of volcano regionally has VEI as the most common event_type.
